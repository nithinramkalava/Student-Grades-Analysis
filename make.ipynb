# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("sem1.csv",index_col=0)
df.head(10)
# Out:
#      HallTicket-No Branch M-II CE  AP PSP DLD CE-LAB AP-LAB PSP-LAB  \
# S.No
# 1       21BQ1A0501    CSE    A  B   A   B   B      A      A      A+
# 2       21BQ1A0502    CSE    A  C   A   D   B      A     A+      A+
# 3       21BQ1A0503    CSE   A+  A   A   D   D      A     A+      A+
# 4       21BQ1A0504    CSE   A+  B  A+   D   C      A     A+      A+
# 5       21BQ1A0505    CSE   A+  A   A   D   C      A      B      A+
# 6       21BQ1A0506    CSE    B  B   A   D   C      A      A      A+
# 7       21BQ1A0507    CSE   A+  B  A+   C   A     A+     A+      A+
# 8       21BQ1A0508    CSE    E  E   D   F   F      B      B       C
# 9       21BQ1A0509    CSE   A+  B  A+   B   B     A+     A+      A+
# 10      21BQ1A0510    CSE   A+  A   A   C   B     A+      A      A+
#
#              ES       LS-2  SGPA  CGPA
# S.No
# 1     COMPLETED  COMPLETED  8.62  8.69
# 2     COMPLETED  COMPLETED  8.23  8.31
# 3     COMPLETED  COMPLETED  8.38  8.50
# 4     COMPLETED  COMPLETED  8.54  8.62
# ...

# %%
grades = {'A+':10,'A':9,'B':8,'C':7,'D':6,'E':5, 'F':0, 'Ab':0}

# %%
df.columns
# Out:
# Index(['HallTicket-No', 'Branch', 'M-II', 'CE', 'AP', 'PSP', 'DLD', 'CE-LAB',
#        'AP-LAB', 'PSP-LAB', 'ES', 'LS-2', 'SGPA', 'CGPA'],
#       dtype='object')

# %%
with open('grades.txt','r') as f:
    data = eval(f.read())
type(data)
# Out:
# dict

# %%
df.head()
# Out:
#      HallTicket-No Branch M-II CE  AP PSP DLD CE-LAB AP-LAB PSP-LAB  \
# S.No
# 1       21BQ1A0501    CSE    A  B   A   B   B      A      A      A+
# 2       21BQ1A0502    CSE    A  C   A   D   B      A     A+      A+
# 3       21BQ1A0503    CSE   A+  A   A   D   D      A     A+      A+
# 4       21BQ1A0504    CSE   A+  B  A+   D   C      A     A+      A+
# 5       21BQ1A0505    CSE   A+  A   A   D   C      A      B      A+
#
#              ES       LS-2  SGPA  CGPA
# S.No
# 1     COMPLETED  COMPLETED  8.62  8.69
# 2     COMPLETED  COMPLETED  8.23  8.31
# 3     COMPLETED  COMPLETED  8.38  8.50
# 4     COMPLETED  COMPLETED  8.54  8.62
# 5     COMPLETED  COMPLETED  8.38  8.08

# %%
df
# Out:
#      HallTicket-No Branch M-II CE  AP PSP DLD CE-LAB AP-LAB PSP-LAB  \
# S.No
# 1       21BQ1A0501    CSE    A  B   A   B   B      A      A      A+
# 2       21BQ1A0502    CSE    A  C   A   D   B      A     A+      A+
# 3       21BQ1A0503    CSE   A+  A   A   D   D      A     A+      A+
# 4       21BQ1A0504    CSE   A+  B  A+   D   C      A     A+      A+
# 5       21BQ1A0505    CSE   A+  A   A   D   C      A      B      A+
# ...            ...    ...  ... ..  ..  ..  ..    ...    ...     ...
# 249     21BQ1A05P0    CSE    A  C   B   B   B      B     A+      A+
# 250     21BQ1A05P1    CSE    C  C   D   C   E      A      A      A+
# 251     21BQ1A05P2    CSE    B  C   B   D   D      A      A       A
# 252     21BQ1A05P3    CSE   A+  A  A+   C   B      A     A+      A+
# 253     21BQ1A05P4    CSE   A+  A  A+   C   B      B     A+      A+
#
#              ES       LS-2  SGPA  CGPA
# S.No
# 1     COMPLETED  COMPLETED  8.62  8.69
# 2     COMPLETED  COMPLETED  8.23  8.31
# ...

# %%
x = np.random.rand()

# %%
np.round(np.random.uniform(7.0,9.4),2)
# Out:
# 7.88

# %%
df['SGPA'] = np.round(np.random.uniform(7.0,9.4,size=df['SGPA'].count()),2)

# %%
df['CGPA'] = df['SGPA']

# %%
df
# Out:
#      HallTicket-No Branch M-II CE  AP PSP DLD CE-LAB AP-LAB PSP-LAB  \
# S.No
# 1       21BQ1A0501    CSE    A  B   A   B   B      A      A      A+
# 2       21BQ1A0502    CSE    A  C   A   D   B      A     A+      A+
# 3       21BQ1A0503    CSE   A+  A   A   D   D      A     A+      A+
# 4       21BQ1A0504    CSE   A+  B  A+   D   C      A     A+      A+
# 5       21BQ1A0505    CSE   A+  A   A   D   C      A      B      A+
# ...            ...    ...  ... ..  ..  ..  ..    ...    ...     ...
# 249     21BQ1A05P0    CSE    A  C   B   B   B      B     A+      A+
# 250     21BQ1A05P1    CSE    C  C   D   C   E      A      A      A+
# 251     21BQ1A05P2    CSE    B  C   B   D   D      A      A       A
# 252     21BQ1A05P3    CSE   A+  A  A+   C   B      A     A+      A+
# 253     21BQ1A05P4    CSE   A+  A  A+   C   B      B     A+      A+
#
#              ES       LS-2  SGPA  CGPA
# S.No
# 1     COMPLETED  COMPLETED  8.81  8.81
# 2     COMPLETED  COMPLETED  9.37  9.37
# ...

# %%
df.to_csv('sem1.csv')
