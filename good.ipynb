# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sem2 = pd.read_csv("sem2.csv",index_col="S.No")
sem2.head()
# Out:
#      HallTicket-No Branch M-II CE  AP PSP DLD CE-LAB AP-LAB PSP-LAB  \
# S.No
# 1       21BQ1A0501    CSE    A  B   A   B   B      A      A      A+
# 2       21BQ1A0502    CSE    A  C   A   D   B      A     A+      A+
# 3       21BQ1A0503    CSE   A+  A   A   D   D      A     A+      A+
# 4       21BQ1A0504    CSE   A+  B  A+   D   C      A     A+      A+
# 5       21BQ1A0505    CSE   A+  A   A   D   C      A      B      A+
#
#              ES       LS-2  SGPA  CGPA
# S.No
# 1     COMPLETED  COMPLETED  8.62  8.69
# 2     COMPLETED  COMPLETED  8.23  8.31
# 3     COMPLETED  COMPLETED  8.38  8.50
# 4     COMPLETED  COMPLETED  8.54  8.62
# 5     COMPLETED  COMPLETED  8.38  8.08

# %%
# # for subject in sem2.columns[2:10]:
# #     sns.barplot(data=)
# sns.scatterplot(data=sem2["PSP"].value_counts(),x=0,y=1)
sem2["M-II"].value_counts()
# Out:
# A+    83
# A     73
# B     41
# C     23
# D     16
# E      9
# F      8
# Name: M-II, dtype: int64

# %%
sem2 = pd.read_csv("sem2.csv",index_col="S.No")
plt.figure(figsize=(15,8),dpi=400)
sns.scatterplot(x="HallTicket-No",y="CE",data=sem2,hue="PSP",style="PSP")
# Out:
# <AxesSubplot:xlabel='HallTicket-No', ylabel='CE'>
